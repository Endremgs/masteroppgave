# %% [markdown]
# # Check correlation between similarities based on disk-based hashes and true similarities

# %%
# from correlation import compute_correlation_similarity
from disk_resolution import plot_disk_dia_layers

# %% [markdown]
# # Plot Pearson correlation coefficient with various layers and resolution

# %% [markdown]
# ## Disk Rome

# %%
plot_disk_dia_layers(
    city="rome",
    layers=[1, 2, 3, 4, 5, 6],
    diameter=[1, 3, 0.2],
    measure="py_dtw_euclidean",
    reference="dtw",
    parallell_jobs=3,
)

plot_disk_dia_layers(
    city="rome",
    layers=[1, 2, 3, 4, 5, 6],
    diameter=[1, 3, 0.2],
    measure="py_dtw_manhattan",
    reference="dtw",
    parallell_jobs=3,
)

plot_disk_dia_layers(
    city="rome",
    layers=[1, 2, 3, 4, 5, 6],
    diameter=[1, 3, 0.2],
    measure="py_dtw_euclidean",
    reference="frechet",
    parallell_jobs=3,
)


plot_disk_dia_layers(
    city="rome",
    layers=[1, 2, 3, 4, 5, 6],
    diameter=[1, 3, 0.2],
    measure="py_dtw_manhattan",
    reference="frechet",
    parallell_jobs=3,
)


# 66 minutes
# plot_disk_dia_layers(
#     "rome",
#     [1, 2, 3, 4, 5, 6],
#     [1, 3, 0.2],
#     measure="py_frechet",
#     reference="frechet",
#     parallell_jobs=1,
# )
# Out:
# L: 6 2.80
# L: 1 1.00
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/opt/homebrew/Cellar/python@3.11/3.11.7_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.11/3.11.7_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#            ^^^^^^^^^^^^^^^^
#   File "/Users/saether/masteroppgave/masteroppgave/hashed_similarities/disk_resolution.py", line 172, in _fun_wrapper_corr
#     edits = _mirrorDiagonal(MEASURE[measure](hashes)).flatten()
#                             ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/saether/masteroppgave/masteroppgave/utils/similarity_measures/distance.py", line 31, in py_dtw_manhattan
#     e_dist = dtw_manhattan(X, Y)[0]
#              ^^^^^^^^^^^^^^^^^^^
#   File "/Users/saether/masteroppgave/masteroppgave/utils/similarity_measures/py/hashed_dtw.py", line 84, in dtw_manhattan
#     s = _get_alphabetical_grid_distance(X[i - 1], Y[j - 1])
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/saether/masteroppgave/masteroppgave/utils/similarity_measures/py/hashed_dtw.py", line 25, in _get_alphabetical_grid_distance
#     x = abs(_get_num_value(hx_1, "A") - _get_num_value(hy_1, "A"))
#             ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/saether/masteroppgave/masteroppgave/utils/similarity_measures/py/hashed_dtw.py", line 8, in _get_num_value
#     return (ord(c1) - ord(base)) * 26 + ord(c2) - ord(base)
#             ^^^^^^^
# TypeError: ord() expected string of length 1, but float found
# """
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 10
#       1 plot_disk_dia_layers(
#       2     "rome",
#       3     [1, 2, 3, 4, 5, 6],
#    (...)
#       7     parallell_jobs=3,
#       8 )
# ---> 10 plot_disk_dia_layers(
#      11     "rome",
#      12     [1, 2, 3, 4, 5, 6],
#      13     [1, 3, 0.2],
#      14     measure="py_dtw_manhattan",
#      15     reference="dtw",
#      16     parallell_jobs=3,
#      17 )
#      19 plot_disk_dia_layers(
#      20     "rome",
#      21     [1, 2, 3, 4, 5, 6],
#    (...)
#      25     parallell_jobs=3,
#      26 )
#      29 plot_disk_dia_layers(
#      30     "rome",
#      31     [1, 2, 3, 4, 5, 6],
#    (...)
#      35     parallell_jobs=3,
#      36 )
#
# File ~/masteroppgave/masteroppgave/hashed_similarities/disk_resolution.py:236, in plot_disk_dia_layers(city, layers, diameter, measure, reference, parallell_jobs)
#     210 def plot_disk_dia_layers(
#     211     city: str,
#     212     layers: list[int],
#    (...)
#     216     parallell_jobs: int = 20,
#     217 ):
#     218     """Visualises the 'optimal' values for resolution and layers for the disk hashes
#     219
#     220     Param
#    (...)
#     233         Yhe number of parallell jobs that will create the data foundation
#     234     """
# --> 236     results = _compute_disk_diameter_layers(
#     237         city, layers, diameter, measure, reference, parallell_jobs
#     238     )
#     240     fig, ax1 = plt.subplots(figsize=(10, 8), dpi=300)
#     241     ax2 = ax1.twinx()
#
# File ~/masteroppgave/masteroppgave/hashed_similarities/disk_resolution.py:197, in _compute_disk_diameter_layers(city, layers, diameter, measure, reference, parallell_jobs)
#     193 print(f"L: {lay}", "{:.2f}".format(dia), end="\r")
#     194 # edits = _mirrorDiagonal(MEASURE[measure](hashes)).flatten()
#     195
#     196 # corr = np.corrcoef(edits, REFERENCE[city.lower()+reference.lower()])[0][1]
# --> 197 corrs = pool.map(
#     198     _fun_wrapper_corr,
#     199     [(city, dia, lay, measure, reference) for _ in range(parallell_jobs)],
#     200 )
#     201 corr = np.average(np.array(corrs))
#     202 std = np.std(np.array(corrs))
#
# File /opt/homebrew/Cellar/python@3.11/3.11.7_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/multiprocessing/pool.py:367, in Pool.map(self, func, iterable, chunksize)
#     362 def map(self, func, iterable, chunksize=None):
#     363     '''
#     364     Apply `func` to each element in `iterable`, collecting the results
#     365     in a list that is returned.
#     366     '''
# --> 367     return self._map_async(func, iterable, mapstar, chunksize).get()
#
# File /opt/homebrew/Cellar/python@3.11/3.11.7_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/multiprocessing/pool.py:774, in ApplyResult.get(self, timeout)
#     772     return self._value
#     773 else:
# --> 774     raise self._value
#
# TypeError: ord() expected string of length 1, but float found

# %% [markdown]
# ## Disk Porto

# %%
plot_disk_dia_layers(
    "porto",
    [1, 2, 3, 4, 5, 6],
    [1, 3, 0.2],
    measure="py_dtw",
    reference="dtw",
    parallell_jobs=3,
)

plot_disk_dia_layers(
    "porto",
    [1, 2, 3, 4, 5, 6],
    [1, 3, 0.2],
    measure="py_dtw",
    reference="frechet",
    parallell_jobs=3,
)

# %% [markdown]
# ## Disk Kolumbus

# %%
plot_disk_dia_layers(
    "kolumbus",
    [1, 2, 3, 4, 5, 6],
    [1, 3, 0.2],
    measure="py_dtw",
    reference="dtw",
    parallell_jobs=3,
)

# NOTE - Frechet true similarites is not computed due to extensive computation time
# plot_disk_dia_layers(
#     "kolumbus",
#     [1, 2, 3, 4, 5, 6],
#     [1, 3, 0.5],
#     measure="py_dtw",
#     reference="frechet",
#     parallell_jobs=3,
# )

# NOTE: Achieves better results than dtw, so keeping it although ED code is removed
# plot_disk_dia_layers(
#     "kolumbus",
#     [1, 2, 3, 4, 5, 6],
#     [1, 3, 0.5],
#     measure="py_ed",
#     reference="frechet",
#     parallell_jobs=3,
# )
