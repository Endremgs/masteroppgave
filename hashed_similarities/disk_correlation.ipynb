# %% [markdown]
# # Check correlation between similarities based on disk-based hashes and true similarities

# %%
# from correlation import compute_correlation_similarity
from disk_resolution import plot_disk_dia_layers

# %% [markdown]
# # Plot Pearson correlation coefficient with various layers and resolution

# %% [markdown]
# ## Disk Rome

# %%
plot_disk_dia_layers(
    "rome",
    [1, 2, 3, 4, 5, 6],
    [1, 3, 0.2],
    measure="py_dtw_euclidean",
    reference="dtw",
    parallell_jobs=3,
)

plot_disk_dia_layers(
    "rome",
    [1, 2, 3, 4, 5, 6],
    [1, 3, 0.2],
    measure="py_dtw_euclidean",
    reference="frechet",
    parallell_jobs=3,
)


# 66 minutes
# plot_disk_dia_layers(
#     "rome",
#     [1, 2, 3, 4, 5, 6],
#     [1, 3, 0.2],
#     measure="py_frechet",
#     reference="frechet",
#     parallell_jobs=1,
# )
# Out:
# L: 6 2.80
# L: 5 2.00
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 10
#       1 plot_disk_dia_layers(
#       2     "rome",
#       3     [1, 2, 3, 4, 5, 6],
#    (...)
#       7     parallell_jobs=3,
#       8 )
# ---> 10 plot_disk_dia_layers(
#      11     "rome",
#      12     [1, 2, 3, 4, 5, 6],
#      13     [1, 3, 0.2],
#      14     measure="py_dtw_euclidean",
#      15     reference="frechet",
#      16     parallell_jobs=3,
#      17 )
#      20 # 66 minutes
#      21 # plot_disk_dia_layers(
#      22 #     "rome",
#    (...)
#      27 #     parallell_jobs=1,
#      28 # )
#
# File ~/masteroppgave/masteroppgave/hashed_similarities/disk_resolution.py:227, in plot_disk_dia_layers(city, layers, diameter, measure, reference, parallell_jobs)
#     201 def plot_disk_dia_layers(
#     202     city: str,
#     203     layers: list[int],
#    (...)
#     207     parallell_jobs: int = 20,
#     208 ):
#     209     """Visualises the 'optimal' values for resolution and layers for the disk hashes
#     210
#     211     Param
#    (...)
#     224         Yhe number of parallell jobs that will create the data foundation
#     225     """
# --> 227     results = _compute_disk_diameter_layers(
#     228         city, layers, diameter, measure, reference, parallell_jobs
#     229     )
#     231     fig, ax1 = plt.subplots(figsize=(10, 8), dpi=300)
#     232     ax2 = ax1.twinx()
#
# File ~/masteroppgave/masteroppgave/hashed_similarities/disk_resolution.py:188, in _compute_disk_diameter_layers(city, layers, diameter, measure, reference, parallell_jobs)
#     184 print(f"L: {lay}", "{:.2f}".format(dia), end="\r")
#     185 # edits = _mirrorDiagonal(MEASURE[measure](hashes)).flatten()
#     186
#     187 # corr = np.corrcoef(edits, REFERENCE[city.lower()+reference.lower()])[0][1]
# --> 188 corrs = pool.map(
#     189     _fun_wrapper_corr,
#     190     [(city, dia, lay, measure, reference) for _ in range(parallell_jobs)],
#     191 )
#     192 corr = np.average(np.array(corrs))
#     193 std = np.std(np.array(corrs))
#
# File /opt/homebrew/Cellar/python@3.11/3.11.7_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/multiprocessing/pool.py:367, in Pool.map(self, func, iterable, chunksize)
#     362 def map(self, func, iterable, chunksize=None):
#     363     '''
#     364     Apply `func` to each element in `iterable`, collecting the results
#     365     in a list that is returned.
#     366     '''
# --> 367     return self._map_async(func, iterable, mapstar, chunksize).get()
#
# File /opt/homebrew/Cellar/python@3.11/3.11.7_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/multiprocessing/pool.py:768, in ApplyResult.get(self, timeout)
#     767 def get(self, timeout=None):
# --> 768     self.wait(timeout)
#     769     if not self.ready():
#     770         raise TimeoutError
#
# File /opt/homebrew/Cellar/python@3.11/3.11.7_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/multiprocessing/pool.py:765, in ApplyResult.wait(self, timeout)
#     764 def wait(self, timeout=None):
# --> 765     self._event.wait(timeout)
#
# File /opt/homebrew/Cellar/python@3.11/3.11.7_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py:629, in Event.wait(self, timeout)
#     627 signaled = self._flag
#     628 if not signaled:
# --> 629     signaled = self._cond.wait(timeout)
#     630 return signaled
#
# File /opt/homebrew/Cellar/python@3.11/3.11.7_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/threading.py:327, in Condition.wait(self, timeout)
#     325 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     326     if timeout is None:
# --> 327         waiter.acquire()
#     328         gotit = True
#     329     else:
#
# KeyboardInterrupt:

# %% [markdown]
# ## Disk Porto

# %%
plot_disk_dia_layers(
    "porto",
    [1, 2, 3, 4, 5, 6],
    [1, 3, 0.2],
    measure="py_dtw",
    reference="dtw",
    parallell_jobs=3,
)

plot_disk_dia_layers(
    "porto",
    [1, 2, 3, 4, 5, 6],
    [1, 3, 0.2],
    measure="py_dtw",
    reference="frechet",
    parallell_jobs=3,
)

# %% [markdown]
# ## Disk Kolumbus

# %%
plot_disk_dia_layers(
    "kolumbus",
    [1, 2, 3, 4, 5, 6],
    [1, 3, 0.2],
    measure="py_dtw",
    reference="dtw",
    parallell_jobs=3,
)

# NOTE - Frechet true similarites is not computed due to extensive computation time
# plot_disk_dia_layers(
#     "kolumbus",
#     [1, 2, 3, 4, 5, 6],
#     [1, 3, 0.5],
#     measure="py_dtw",
#     reference="frechet",
#     parallell_jobs=3,
# )

# NOTE: Achieves better results than dtw, so keeping it although ED code is removed
# plot_disk_dia_layers(
#     "kolumbus",
#     [1, 2, 3, 4, 5, 6],
#     [1, 3, 0.5],
#     measure="py_ed",
#     reference="frechet",
#     parallell_jobs=3,
# )
