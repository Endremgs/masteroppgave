# %% [markdown]
# # Correlation between hash schemes and true similarities with various datasizes

# %%
# from correlation import compute_correlation_similarity
from grid_resolution import plot_grid_sizes

# %% [markdown]
# ## Grid

# %% [markdown]
# #### DTW

# %%
plot_grid_sizes(
    city="rome",
    layer=2,
    resolution=1.0,
    measure="dtw",
    reference="dtw",
    sizes=[50, 100, 200, 300, 400, 500],
    parallel_jobs=10,
)
# Out:
# Results:  [[0.756707704847055, 1.0, 0.004905552303474281, 50, 'porto'], [0.7725795920722356, 1.0, 0.006257454054337586, 100, 'porto'], [0.7056431897277868, 1.0, 0.0018483796166579025, 200, 'porto']]
# Results:  [[0.55485804348733, 1.0, 0.05755150191348274, 50, 'rome'], [0.5862536588661127, 1.0, 0.02808130469837783, 100, 'rome'], [0.5948779494043668, 1.0, 0.011518509414321199, 200, 'rome']]
# Results:  [[0.8987271717487242, 1.0, 0.01865675848723264, 50, 'kolumbus'], [0.9208215939957513, 1.0, 0.011281645820237385, 100, 'kolumbus'], [0.9241081733452492, 1.0, 0.009792122005718162, 200, 'kolumbus']]
# All results:  [[[0.756707704847055, 1.0, 0.004905552303474281, 50, 'porto'], [0.7725795920722356, 1.0, 0.006257454054337586, 100, 'porto'], [0.7056431897277868, 1.0, 0.0018483796166579025, 200, 'porto']], [[0.55485804348733, 1.0, 0.05755150191348274, 50, 'rome'], [0.5862536588661127, 1.0, 0.02808130469837783, 100, 'rome'], [0.5948779494043668, 1.0, 0.011518509414321199, 200, 'rome']], [[0.8987271717487242, 1.0, 0.01865675848723264, 50, 'kolumbus'], [0.9208215939957513, 1.0, 0.011281645820237385, 100, 'kolumbus'], [0.9241081733452492, 1.0, 0.009792122005718162, 200, 'kolumbus']]]

# %% [markdown]
# #### Fréchet

# %%
# TODO: for frechet
