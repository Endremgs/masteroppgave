# %% [markdown]
# # Correlation between hash schemes and true similarities with various datasizes

# %%
# from correlation import compute_correlation_similarity
from grid_resolution import plot_grid_sizes

# %% [markdown]
# ## Grid

# %% [markdown]
# #### DTW

# %%
plot_grid_sizes(
    city="rome",
    layer=2,
    resolution=1.0,
    measure="dtw",
    reference="dtw",
    sizes=[50, 100, 200, 300, 400, 500],
    parallel_jobs=2,
)
# Out:
# Avg correlation:  0.553542453105552
# Standard deviation:  0.0208491241177039
# Avg correlation:  0.6161225325371903
# Standard deviation:  0.012585985397701949
# Avg correlation:  0.625769535456196
# Standard deviation:  0.004230922521859748
# Avg correlation:  0.5874516593934717
# Standard deviation:  0.0005579803445229237
# Avg correlation:  0.5769364631023752
# Standard deviation:  0.010251243972769775
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Avg correlation:  0.5841741979769972
# Standard deviation:  0.011743288620425285
# Results:  [[0.553542453105552, 1.0, 0.0208491241177039, 50], [0.6161225325371903, 1.0, 0.012585985397701949, 100], [0.625769535456196, 1.0, 0.004230922521859748, 200], [0.5874516593934717, 1.0, 0.0005579803445229237, 300], [0.5769364631023752, 1.0, 0.010251243972769775, 400], [0.5841741979769972, 1.0, 0.011743288620425285, 500]]

# %% [markdown]
# #### Fréchet

# %%
# TODO: for frechet
